# %% [markdown]
# # Analisando a distribuição de idades

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
imdb = pd.read_csv("imdb.csv")

# %%
imdb.describe()
# Out:
#                  AGE         GENDER    FACE_SCORE  SECOND_FACE_SCORE
# count  460723.000000  452261.000000  4.607230e+05      213797.000000
# mean       36.441267       0.581996          -inf           2.452904
# std        35.521171       0.493231           NaN           1.064432
# min       -31.000000       0.000000          -inf           0.730926
# 25%        27.000000       0.000000  1.757891e+00           1.583692
# 50%        34.000000       1.000000  2.980097e+00           2.355163
# 75%        43.000000       1.000000  4.006376e+00           3.228071
# max      2014.000000       1.000000  7.381689e+00           6.395435

# %%
import scipy.stats as ss
figure(figsize=(30,20))
plt.xlabel("AGE_IMDB", fontsize=20)
plt.ylabel("Numbers of Samples",fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
imdb.AGE.hist( bins=200,range=(-10,100),facecolor="r",edgecolor='black')

# %%
figure(figsize=(10,10))
plt.xlabel("GENDER_IMDB", fontsize=20)
plt.ylabel("Numbers of Samples",fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
imdb.GENDER.hist()

# %%
wiki = pd.read_csv("wiki.csv")

# %%
figure(figsize=(30,20))
plt.xlabel("AGE_WIKI", fontsize=20)
plt.ylabel("Numbers of Samples",fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
wiki.AGE.hist( bins=200,range=(-10,100),facecolor="r",edgecolor='black')

# %%
wiki.describe()
# Out:
#                 AGE        GENDER    FACE_SCORE  SECOND_FACE_SCORE
# count  62328.000000  59685.000000  6.232800e+04        4096.000000
# mean      36.051181      0.788523          -inf           2.009050
# std       23.870078      0.408359           NaN           0.981277
# min      -75.000000      0.000000          -inf           0.731419
# 25%       23.000000      1.000000          -inf           1.164925
# 50%       30.000000      1.000000  2.463949e+00           1.839065
# 75%       46.000000      1.000000  3.760014e+00           2.655757
# max     1995.000000      1.000000  7.081268e+00           5.463147

# %%
figure(figsize=(10,10))
plt.xlabel("GENDER_WIKI", fontsize=20)
plt.ylabel("Numbers of Samples",fontsize=20)
plt.tick_params(axis='both', which='major', labelsize=20)
wiki.GENDER.hist()
